# %% [markdown]
# ### Pandas_Plot_Series_DataFrame

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame()

# %% [markdown]
# ### plot
#
# #### kind: str
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2020', periods=1000))
# random한 1000개의 수를 2020년 1월1일부터 1000일 동안 시계열 데이터 생성

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()
# cumsum : 누적합

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                 index=ts.index, columns=list('ABCD'))
df
# 1000개의 행과 4개의 열 생성 확인
# Out:
#                    A         B         C         D
# 2020-01-01  0.586206  0.950872 -1.510095 -0.969780
# 2020-01-02 -0.816316 -0.398224 -1.065655 -0.923218
# 2020-01-03 -1.149512 -0.215985  0.131490 -0.149574
# 2020-01-04 -0.387225 -0.991163  0.799623 -0.242841
# 2020-01-05 -0.364121 -0.192197 -0.740611 -0.024660
# ...              ...       ...       ...       ...
# 2022-09-22  0.557432  0.175470  1.502713  0.008054
# 2022-09-23  1.453543 -1.180016  0.856657 -1.339425
# 2022-09-24 -3.091540 -1.154132  0.325895 -0.154448
# 2022-09-25 -0.329408  0.690487  0.034886 -0.698014
# 2022-09-26 -1.320529 -0.257853 -1.027571 -0.882984
#
# [1000 rows x 4 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = df.cumsum()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000,2), columns=['B','C']).cumsum()
df3.head()
# Out:
#           B         C
# 0  1.634196 -2.266574
# 1  0.593394 -2.887567
# 2  0.941502 -3.030646
# 3  1.993678 -1.526493
# 4  2.853863 -0.620855

# %%
df3['A'] = pd.Series(list(range(len(df)))) # A 컬럼생성 (index 형태)
df3.head()
# Out:
#           B         C  A
# 0  1.634196 -2.266574  0
# 1  0.593394 -2.887567  1
# 2  0.941502 -3.030646  2
# 3  1.993678 -1.526493  3
# 4  2.853863 -0.620855  4

# %%
df3.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>
