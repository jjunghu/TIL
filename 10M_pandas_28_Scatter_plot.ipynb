# %% [markdown]
# ### Scatter plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.484015  0.019903  0.897839  0.628698
# 1  0.596315  0.964844  0.547639  0.860805
# 2  0.043857  0.295924  0.919310  0.297521
# 3  0.821079  0.995668  0.140274  0.240892
# 4  0.287997  0.980289  0.714189  0.221102

# %%
df.plot.scatter(x='a', y='b', s=30, grid=True)  # x, y 값 반드시 지정
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkRed', label='Group 1')
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax)
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %%
df.plot.scatter(x='a', y='b', c='c', s=100)  # 3개의 축 생성, 비교
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
