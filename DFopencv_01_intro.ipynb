# %%
# ! pip install opencv-python

# %%
import cv2
import numpy as np
import sys

# %%
# Opencv 참고자료
# docs.opencv.org

# %% [markdown]
# ### 영상 읽기

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp')

print(type(img))
print('image dimension = ', img.shape)

if img is None : 
    print('image read failed')
    sys.exit()

# Window 만들기
cv2.namedWindow('image')
cv2.imshow('image', img)

# Keyboard 입력 (모든 키) 를 기다리는 동안 영상을 출력
cv2.waitKey()

# 키보드 입력을 받으면 화면에 나타난 모든 창을 닫음
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# image dimension =  (480, 640, 3)

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/camping.jpg',
                cv2.IMREAD_REDUCED_GRAYSCALE_4)

if img is None : 
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### 영상 resize하기

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy_1280_853.jpg',
                cv2.IMREAD_UNCHANGED)    # 파일 속성대로 읽기

if img is None : 
    print('image read failed')
    sys.exit()
    
print(img.shape)
    
img_re = cv2.resize(img, (240, 320), interpolation = cv2.INTER_AREA)
img_re2 = cv2.resize(img, (320, 240), interpolation = cv2.INTER_AREA)
    
cv2.namedWindow('puppy')
cv2.namedWindow('puppy_re')
cv2.namedWindow('puppy_re2')

cv2.imshow('puppy', img)
cv2.imshow('puppy_re', img_re)
cv2.imshow('puppy_re2', img_re2)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (853, 1280, 3)

# %% [markdown]
# ### image 저장하기 cv2.write

# %%
# cv2.imwrite(filename, img, params = None) -> retval

# filename : 저장할 파일 이름
# img : 저장할 자료 (numpy.ndarray)
# params : 파일저장 옵션
#retval : 성공 True, 실패 False

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp',
                cv2.IMREAD_UNCHANGED)

if img is None : 
    print('image read failed')
    sys.exit()
    
img_re = cv2.resize(img, (320, 240), cv2.INTER_AREA)
    
cv2.namedWindow('image')
cv2.namedWindow('image_re')

cv2.imshow('image', img)
cv2.imshow('image_re', img_re)

cv2.imwrite('puppy_resize.png', img_re)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### 새 창 띄우기 cv2.namedWindow()

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy_1280_853.jpg',
                cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
# cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE) -> default
cv2.namedWindow('image', cv2.WINDOW_NORMAL)  # 사진 창 크기 조절 가능
cv2.imshow('image', img)

cv2.waitKey()

cv2.destroyAllWindows()

# %%
# cv2.WINDOW_NORMAL: 영상크기를 창 크기에 맞게 지정
# cv2.WINDOW_AUTOSIZE: 창크기를 영상 크기에 맞게 변경

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy_1280_853.jpg',
                cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
cv2.moveWindow('image', 400, 100)   # winName, x, y

cv2.imshow('image', img)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### 키보드 입력대기: cv2.waitKey()

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp',
                cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)

cv2.waitKey(3000)     # 3초 뒤 자동으로 꺼짐
cv2.destroyAllWindows()

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp',
                cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)

while True : 
    if cv2.waitKey() == 27 :   # ASKII Code값: 27 -> ESC를 눌러야 사라짐
        break
        
cv2.destroyAllWindows()

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)

while True : 
    key = cv2.waitKey()
    if key == 27 or key == ord('q') :  # ASKII Code를 몰라도 q 누르면 없어짐
        break
        
cv2.destroyAllWindows()

# %% [markdown]
# ### matplotlib 라이브러리를 이용한 영상출력

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()

cv2.namedWindow('image')
cv2.imshow('image', img)
    
plt.imshow(img)
plt.axis('off')
plt.show()

while True : 
    if cv2.waitKey() == 27 : 
        break
        
cv2.destroyAllWindows()

# opencv는 BGR로 사진을 인식
# matplotlib는 RGB로 사진을 인식

# %%
# BGR image
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp',
                cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
# RGB로 변환
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(imgRGB)
plt.axis('off')
plt.show()

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp',
                cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
imgGRAY = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(imgGRAY, cmap = 'gray')  # gray는 cmap 조건을 달아주어야함
plt.axis('off')
plt.show()

# %%
img = cv2.imread('./Ch_1_Opencv_Intro/fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None : 
    print('image read failed')
    sys.exit()
    
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgGRAY = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize = (12, 6))
plt.subplot(131), plt.imshow(img), plt.axis('off')
plt.subplot(132), plt.imshow(imgRGB), plt.axis('off')
plt.subplot(133), plt.imshow(imgGRAY, cmap = 'gray'), plt.axis('off')
plt.show()

# %% [markdown]
# ### 이미지 슬라이드쇼

# %%
import os

# %%
img_list = os.listdir('./Ch_1_Opencv_Intro/fig/images/')

print(img_list)
# Out:
# ['autumn_forest_park_128379_1920x1080.jpg', 'boat_mountains_lake_135258_1920x1080.jpg', 'forest_fog_trees_128751_1920x1080.jpg', 'pier_dock_sea_dusk_shore_118549_1920x1080.jpg', 'road_marking_evening_clouds_horizon_120298_1920x1080.jpg']

# %%
img_path = []

for i in img_list : 
    img_path_all = './Ch_1_Opencv_Intro/fig/images/' + i
    img_path.append(img_path_all)
    
img_path
# Out:
# ['./Ch_1_Opencv_Intro/fig/images/autumn_forest_park_128379_1920x1080.jpg',
#  './Ch_1_Opencv_Intro/fig/images/boat_mountains_lake_135258_1920x1080.jpg',
#  './Ch_1_Opencv_Intro/fig/images/forest_fog_trees_128751_1920x1080.jpg',
#  './Ch_1_Opencv_Intro/fig/images/pier_dock_sea_dusk_shore_118549_1920x1080.jpg',
#  './Ch_1_Opencv_Intro/fig/images/road_marking_evening_clouds_horizon_120298_1920x1080.jpg']

# %%
## 이미지가 전체 다 돌면 저절로 꺼지는 이미지 슬라이드

img_path = []

for i in img_list : 
    img_path_all = './Ch_1_Opencv_Intro/fig/images/' + i
    img_path.append(img_path_all)

    
## 전체 화면으로 'image' 창 생성
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN,
                     cv2.WINDOW_FULLSCREEN)

for i in img_path : 
    img = cv2.imread(i, cv2.IMREAD_COLOR)
    
    cv2.imshow('image', img)
    
    cv2.waitKey(2000)
    
cv2.destroyAllWindows()

# %%
## 키 입력을 받기 전에 꺼지지 않는 이미지 슬라이드

img_path = []

for i in img_list : 
    img_path_all = './Ch_1_Opencv_Intro/fig/images/' + i
    img_path.append(img_path_all)
    
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN,
                     cv2.WINDOW_FULLSCREEN)

idx = 0

while True : 
    img_name = img_path[idx]
    img = cv2.imread(img_name, cv2.IMREAD_COLOR)
    
    cv2.imshow('image', img)
    
    if cv2.waitKey(2000) == 27 : 
        break
        
    idx += 1
    
    if idx >= len(img_path) : 
        idx = 0
        
cv2.destroyAllWindows()

# %%
import glob

# %%
img_list = glob.glob('./Ch_1_Opencv_Intro/fig/images/*jpg')

cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN,
                     cv2.WINDOW_FULLSCREEN)

idx = 0

while True : 
    img = cv2.imread(img_list[idx])
    
    if img is None : 
        print('image read failed')
        sys.exit()
    
    cv2.imshow('image', img)
    
    if cv2.waitKey() == 27 : 
        break
        
    idx += 1
    
    if idx >= len(img_list) : 
        idx = 0
        
cv2.destroyAllWindows()
