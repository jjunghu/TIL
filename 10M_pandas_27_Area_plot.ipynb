# %% [markdown]
# ### Area Plot

# %% [markdown]
# - df.plot.area(gird=True)
#   - NaN이 있으면 0으로 채움
#   - grid=True: 격자 표현 옵션
#
#
# - df.plot.area(stacked=False, grid=True)
#   - Area Plot: stacked=True가 Default

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10,4), columns = ['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.907923  0.061248  0.027022  0.827760
# 1  0.024723  0.553940  0.066310  0.358363
# 2  0.982340  0.392292  0.764871  0.922489
# 3  0.422580  0.422716  0.149959  0.423108
# 4  0.866033  0.391680  0.092533  0.053746

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(gid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False, grid=True)
# area plot은 stacked=True가 default임
# Out:
# <AxesSubplot:>
